# %% [markdown]
# # 1. Import and Install Dependencies

# %%
#!pip install tensorflow==2.5.1 tensorflow-gpu==2.5.1 opencv-python mediapipe sklearn matplotlib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
        # Make detections
        image, results = mediapipe_detection(frame, holistic)

        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
#len(results.left_hand_landmarks.landmark)

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.face_landmarks.landmark)
# Out:
# 468

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    #lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    #rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.48972869,  0.53771192, -0.73477489, ...,  0.        ,
#         0.        ,  0.        ])

# %%
468*3+33*4+21*3+21*3
# Out:
# 1662

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.48972869,  0.53771192, -0.73477489, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello','family','thank_you','please','help','yes','NO','sorry','house'])
#path='vid/'

# Thirty videos worth of data
no_sequences = 9

# Videos are going to be 30 frames in length
sequence_length = 9

# %%
# hello
## 0
## 1
## 2
## ...
## 29
# thanks

# I love you

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
import time
start = time.time()
"the code you want to test stays here"
for action in actions:
    cap = cv2.VideoCapture(0)
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions

        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

    
end = time.time()
print(end - start)
# Out:
# 250.87486290931702

# %%
cap.release()
cv2.destroyAllWindows()

# %%
keypoints
# Out:
# array([ 0.51172704,  0.44834006, -0.67493641, ...,  0.        ,
#         0.        ,  0.        ])

# %%
lh
# Out:
# array([ 7.87089407e-01,  8.53811383e-01,  2.85734103e-07,  7.27117538e-01,
#         8.19636047e-01, -1.60164982e-02,  6.77000046e-01,  7.61359453e-01,
#        -2.25866642e-02,  6.41720116e-01,  7.14727700e-01, -2.91422158e-02,
#         6.09224737e-01,  6.86101258e-01, -3.53311710e-02,  7.17768788e-01,
#         6.64053738e-01, -5.03086532e-03,  6.89508319e-01,  5.88860810e-01,
#        -1.69577524e-02,  6.74451351e-01,  5.43674588e-01, -2.83248313e-02,
#         6.62441611e-01,  5.05511045e-01, -3.74642275e-02,  7.54930139e-01,
#         6.51271939e-01, -9.66983568e-03,  7.35586107e-01,  5.68959713e-01,
#        -1.85726173e-02,  7.24354923e-01,  5.18038154e-01, -2.98301969e-02,
#         7.14837730e-01,  4.76482630e-01, -3.87617350e-02,  7.92996824e-01,
#         6.57069921e-01, -1.77233499e-02,  7.86962926e-01,  5.82847178e-01,
#        -3.09246331e-02,  7.82340229e-01,  5.36261439e-01, -4.20759432e-02,
#         7.76847124e-01,  4.95124578e-01, -5.02146818e-02,  8.31013203e-01,
#         6.78394318e-01, -2.74385363e-02,  8.50000262e-01,  6.27683580e-01,
#        -4.03639376e-02,  8.61650407e-01,  5.92803121e-01, -4.66335788e-02,
#         8.70722532e-01,  5.59762597e-01, -5.09153455e-02])

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0,
#  'family': 1,
#  'thank_you': 2,
#  'please': 3,
#  'help': 4,
#  'yes': 5,
#  'NO': 6,
#  'sorry': 7,
#  'house': 8}

# %%
sequences, labels = [], []
s=0
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
            s+=1
        sequences.append(window)
        labels.append(label_map[action])
print(s)
# Out:
# 729

# %%
np.array(sequences).shape
# Out:
# (81, 9, 1662)

# %%
np.array(sequences).shape
# Out:
# (81, 9, 1662)

# %%
np.array(labels).shape
# Out:
# (81,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (81, 9, 1662)

# %%
y = to_categorical(labels,num_classes=9).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 9)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(9,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, 0.2, 0.1,0.3,0.4,0.5,0.6,0.8,0.9]

# %%
actions[np.argmax(res)]
# Out:
# 'house'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
X_train.shape
# Out:
# (76, 9, 1662)

# %%
y_train.shape
# Out:
# (76, 9)

# %%
X_test.shape
# Out:
# (5, 9, 1662)

# %%
y_test.shape
# Out:
# (5, 9)

# %%
model.fit(X_train, y_train, epochs=3000, callbacks=[tb_callback])
# Out:
# Epoch 1/3000
# 3/3 [==============================] - 1s 37ms/step - loss: 2.2043 - categorical_accuracy: 0.1184
# Epoch 2/3000
# 3/3 [==============================] - 0s 50ms/step - loss: 2.2074 - categorical_accuracy: 0.1053
# Epoch 3/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 2.1952 - categorical_accuracy: 0.1579
# Epoch 4/3000
# 3/3 [==============================] - 0s 52ms/step - loss: 2.2079 - categorical_accuracy: 0.1184
# Epoch 5/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 2.1902 - categorical_accuracy: 0.1184
# Epoch 6/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 2.1912 - categorical_accuracy: 0.1184
# Epoch 7/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 2.1951 - categorical_accuracy: 0.1184
# Epoch 8/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 2.1838 - categorical_accuracy: 0.1842
# Epoch 9/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 2.1863 - categorical_accuracy: 0.1316
# Epoch 10/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 2.1801 - categorical_accuracy: 0.2105
# Epoch 11/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 2.1757 - categorical_accuracy: 0.1053
# Epoch 12/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 2.1648 - categorical_accuracy: 0.1053
# Epoch 13/3000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.1468 - categorical_accuracy: 0.1316
# Epoch 14/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 2.1050 - categorical_accuracy: 0.1579
# Epoch 15/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 2.0932 - categorical_accuracy: 0.1053
# Epoch 16/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.9909 - categorical_accuracy: 0.2368
# Epoch 17/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 2.0201 - categorical_accuracy: 0.1711
# Epoch 18/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.8718 - categorical_accuracy: 0.1974
# Epoch 19/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.9351 - categorical_accuracy: 0.2895
# Epoch 20/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.9353 - categorical_accuracy: 0.2105
# Epoch 21/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.8507 - categorical_accuracy: 0.3026
# Epoch 22/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.7649 - categorical_accuracy: 0.2500
# Epoch 23/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.7148 - categorical_accuracy: 0.2632
# Epoch 24/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.6537 - categorical_accuracy: 0.3026
# Epoch 25/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.5818 - categorical_accuracy: 0.2895
# Epoch 26/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.5704 - categorical_accuracy: 0.3421
# Epoch 27/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.4944 - categorical_accuracy: 0.3684
# Epoch 28/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.7281 - categorical_accuracy: 0.2500
# Epoch 29/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.5148 - categorical_accuracy: 0.3816
# Epoch 30/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.4659 - categorical_accuracy: 0.4474
# Epoch 31/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3845 - categorical_accuracy: 0.4211
# Epoch 32/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2774 - categorical_accuracy: 0.5263
# Epoch 33/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.6772 - categorical_accuracy: 0.2368
# Epoch 34/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.4512 - categorical_accuracy: 0.3289
# Epoch 35/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.5164 - categorical_accuracy: 0.2237
# Epoch 36/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.9105 - categorical_accuracy: 0.1711
# Epoch 37/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.8751 - categorical_accuracy: 0.1447
# Epoch 38/3000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.6138 - categorical_accuracy: 0.2632
# Epoch 39/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.4701 - categorical_accuracy: 0.4474
# Epoch 40/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.6127 - categorical_accuracy: 0.3289
# Epoch 41/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.5316 - categorical_accuracy: 0.2763
# Epoch 42/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3685 - categorical_accuracy: 0.5000
# Epoch 43/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2958 - categorical_accuracy: 0.4079
# Epoch 44/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2858 - categorical_accuracy: 0.3553
# Epoch 45/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.1893 - categorical_accuracy: 0.3684
# Epoch 46/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 1.1161 - categorical_accuracy: 0.4737
# Epoch 47/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0751 - categorical_accuracy: 0.5000
# Epoch 48/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.0611 - categorical_accuracy: 0.4474
# Epoch 49/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.0896 - categorical_accuracy: 0.4605
# Epoch 50/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9867 - categorical_accuracy: 0.5395
# Epoch 51/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2215 - categorical_accuracy: 0.3947
# Epoch 52/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5079 - categorical_accuracy: 0.3816
# Epoch 53/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4957 - categorical_accuracy: 0.3421
# Epoch 54/3000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4492 - categorical_accuracy: 0.3289
# Epoch 55/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.4106 - categorical_accuracy: 0.3289
# Epoch 56/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.4230 - categorical_accuracy: 0.3026
# Epoch 57/3000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.2757 - categorical_accuracy: 0.4605
# Epoch 58/3000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.1885 - categorical_accuracy: 0.4737
# Epoch 59/3000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.2306 - categorical_accuracy: 0.3553
# Epoch 60/3000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1869 - categorical_accuracy: 0.4737
# Epoch 61/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 1.0970 - categorical_accuracy: 0.5000
# Epoch 62/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.9805 - categorical_accuracy: 0.6316
# Epoch 63/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9517 - categorical_accuracy: 0.5921
# Epoch 64/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.1079 - categorical_accuracy: 0.3553
# Epoch 65/3000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.1007 - categorical_accuracy: 0.5000
# Epoch 66/3000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4425 - categorical_accuracy: 0.3684
# Epoch 67/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3268 - categorical_accuracy: 0.4211
# Epoch 68/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4806 - categorical_accuracy: 0.3289
# Epoch 69/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.4296 - categorical_accuracy: 0.3816
# Epoch 70/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3853 - categorical_accuracy: 0.3553
# Epoch 71/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3916 - categorical_accuracy: 0.3684
# Epoch 72/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.2567 - categorical_accuracy: 0.4342
# Epoch 73/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.2665 - categorical_accuracy: 0.3947
# Epoch 74/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.2365 - categorical_accuracy: 0.4342
# Epoch 75/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 1.0819 - categorical_accuracy: 0.5789
# Epoch 76/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0683 - categorical_accuracy: 0.4868
# Epoch 77/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 1.0449 - categorical_accuracy: 0.5263
# Epoch 78/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9536 - categorical_accuracy: 0.5921
# Epoch 79/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0373 - categorical_accuracy: 0.5000
# Epoch 80/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.9594 - categorical_accuracy: 0.5395
# Epoch 81/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8966 - categorical_accuracy: 0.6053
# Epoch 82/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9315 - categorical_accuracy: 0.5658
# Epoch 83/3000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.9265 - categorical_accuracy: 0.5658
# Epoch 84/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.8654 - categorical_accuracy: 0.5658
# Epoch 85/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.0616 - categorical_accuracy: 0.5263
# Epoch 86/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0606 - categorical_accuracy: 0.5132
# Epoch 87/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.1066 - categorical_accuracy: 0.4605
# Epoch 88/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0509 - categorical_accuracy: 0.5000
# Epoch 89/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4657 - categorical_accuracy: 0.3421
# Epoch 90/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.7364 - categorical_accuracy: 0.2895
# Epoch 91/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5218 - categorical_accuracy: 0.2632
# Epoch 92/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.2188 - categorical_accuracy: 0.3421
# Epoch 93/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.1290 - categorical_accuracy: 0.4868
# Epoch 94/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.2561 - categorical_accuracy: 0.3947
# Epoch 95/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.2441 - categorical_accuracy: 0.4211
# Epoch 96/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0488 - categorical_accuracy: 0.6316
# Epoch 97/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.1565 - categorical_accuracy: 0.4474
# Epoch 98/3000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.0420 - categorical_accuracy: 0.5263
# Epoch 99/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9745 - categorical_accuracy: 0.6053
# Epoch 100/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9618 - categorical_accuracy: 0.5789
# Epoch 101/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.9003 - categorical_accuracy: 0.5658
# Epoch 102/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8672 - categorical_accuracy: 0.6447
# Epoch 103/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8529 - categorical_accuracy: 0.6316
# Epoch 104/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.8735 - categorical_accuracy: 0.5526
# Epoch 105/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.9035 - categorical_accuracy: 0.6184
# Epoch 106/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8814 - categorical_accuracy: 0.5658
# Epoch 107/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.8551 - categorical_accuracy: 0.6053
# Epoch 108/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8514 - categorical_accuracy: 0.6053
# Epoch 109/3000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.8507 - categorical_accuracy: 0.6053
# Epoch 110/3000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.4489 - categorical_accuracy: 0.4342
# Epoch 111/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.7433 - categorical_accuracy: 0.3947
# Epoch 112/3000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1339 - categorical_accuracy: 0.4342
# Epoch 113/3000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1665 - categorical_accuracy: 0.5000
# Epoch 114/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0951 - categorical_accuracy: 0.5526
# Epoch 115/3000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0587 - categorical_accuracy: 0.5658
# Epoch 116/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1700 - categorical_accuracy: 0.4342
# Epoch 117/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1013 - categorical_accuracy: 0.5395
# Epoch 118/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9790 - categorical_accuracy: 0.5658
# Epoch 119/3000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.9816 - categorical_accuracy: 0.4737
# Epoch 120/3000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9000 - categorical_accuracy: 0.6053
# Epoch 121/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.9135 - categorical_accuracy: 0.5789
# Epoch 122/3000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.9627 - categorical_accuracy: 0.5789
# Epoch 123/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0192 - categorical_accuracy: 0.5526
# Epoch 124/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.0890 - categorical_accuracy: 0.5132
# Epoch 125/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.9122 - categorical_accuracy: 0.5263
# Epoch 126/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.8676 - categorical_accuracy: 0.6316
# Epoch 127/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0506 - categorical_accuracy: 0.5263
# Epoch 128/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3138 - categorical_accuracy: 0.3816
# Epoch 129/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2178 - categorical_accuracy: 0.4737
# Epoch 130/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 1.1945 - categorical_accuracy: 0.5132
# Epoch 131/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1392 - categorical_accuracy: 0.4474
# Epoch 132/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1937 - categorical_accuracy: 0.4079
# Epoch 133/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0958 - categorical_accuracy: 0.4342
# Epoch 134/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.1472 - categorical_accuracy: 0.4605
# Epoch 135/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 1.0743 - categorical_accuracy: 0.5000
# Epoch 136/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9905 - categorical_accuracy: 0.5921
# Epoch 137/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9456 - categorical_accuracy: 0.5921
# Epoch 138/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0139 - categorical_accuracy: 0.5000
# Epoch 139/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9352 - categorical_accuracy: 0.5526
# Epoch 140/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8664 - categorical_accuracy: 0.6184
# Epoch 141/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8398 - categorical_accuracy: 0.6316
# Epoch 142/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.8407 - categorical_accuracy: 0.5921
# Epoch 143/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8087 - categorical_accuracy: 0.6316
# Epoch 144/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7823 - categorical_accuracy: 0.6053
# Epoch 145/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7750 - categorical_accuracy: 0.5921
# Epoch 146/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7361 - categorical_accuracy: 0.6711
# Epoch 147/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7332 - categorical_accuracy: 0.6447
# Epoch 148/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7061 - categorical_accuracy: 0.6711
# Epoch 149/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6760 - categorical_accuracy: 0.7105
# Epoch 150/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7086 - categorical_accuracy: 0.7105
# Epoch 151/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.8485 - categorical_accuracy: 0.6579
# Epoch 152/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7174 - categorical_accuracy: 0.7105
# Epoch 153/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1001 - categorical_accuracy: 0.5263
# Epoch 154/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.9698 - categorical_accuracy: 0.5000
# Epoch 155/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1262 - categorical_accuracy: 0.5395
# Epoch 156/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1928 - categorical_accuracy: 0.4079
# Epoch 157/3000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.6411 - categorical_accuracy: 0.2632
# Epoch 158/3000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.0877 - categorical_accuracy: 0.5395
# Epoch 159/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9373 - categorical_accuracy: 0.6184
# Epoch 160/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9095 - categorical_accuracy: 0.5921
# Epoch 161/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0411 - categorical_accuracy: 0.5395
# Epoch 162/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0085 - categorical_accuracy: 0.6184
# Epoch 163/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8882 - categorical_accuracy: 0.6053
# Epoch 164/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8153 - categorical_accuracy: 0.6579
# Epoch 165/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.9474 - categorical_accuracy: 0.5263
# Epoch 166/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7528 - categorical_accuracy: 0.7105
# Epoch 167/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7776 - categorical_accuracy: 0.6974
# Epoch 168/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7483 - categorical_accuracy: 0.7237
# Epoch 169/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7573 - categorical_accuracy: 0.6711
# Epoch 170/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7194 - categorical_accuracy: 0.6974
# Epoch 171/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7339 - categorical_accuracy: 0.6974
# Epoch 172/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7070 - categorical_accuracy: 0.6974
# Epoch 173/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6845 - categorical_accuracy: 0.6842
# Epoch 174/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6640 - categorical_accuracy: 0.7500
# Epoch 175/3000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6155 - categorical_accuracy: 0.7368
# Epoch 176/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6373 - categorical_accuracy: 0.6974
# Epoch 177/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6318 - categorical_accuracy: 0.6579
# Epoch 178/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6541 - categorical_accuracy: 0.7105
# Epoch 179/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.5816 - categorical_accuracy: 0.7632
# Epoch 180/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.5796 - categorical_accuracy: 0.7763
# Epoch 181/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.9411 - categorical_accuracy: 0.5132
# Epoch 182/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7300 - categorical_accuracy: 0.6447
# Epoch 183/3000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.8521 - categorical_accuracy: 0.6184
# Epoch 184/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6219 - categorical_accuracy: 0.7500
# Epoch 185/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.7572 - categorical_accuracy: 0.6842
# Epoch 186/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.7726 - categorical_accuracy: 0.6053
# Epoch 187/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7832 - categorical_accuracy: 0.6447
# Epoch 188/3000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.8397 - categorical_accuracy: 0.6711
# Epoch 189/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.1326 - categorical_accuracy: 0.4868
# Epoch 190/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.4868 - categorical_accuracy: 0.3553
# Epoch 191/3000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.1645 - categorical_accuracy: 0.4474
# Epoch 192/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.9053 - categorical_accuracy: 0.5526
# Epoch 193/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.9039 - categorical_accuracy: 0.5658
# Epoch 194/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.7860 - categorical_accuracy: 0.6184
# Epoch 195/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8696 - categorical_accuracy: 0.6053
# Epoch 196/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7968 - categorical_accuracy: 0.6447
# Epoch 197/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.7841 - categorical_accuracy: 0.6184
# Epoch 198/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7270 - categorical_accuracy: 0.6842
# Epoch 199/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.7551 - categorical_accuracy: 0.6184
# Epoch 200/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.6799 - categorical_accuracy: 0.7237
# Epoch 201/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.5969 - categorical_accuracy: 0.7632
# Epoch 202/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6164 - categorical_accuracy: 0.7237
# Epoch 203/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6203 - categorical_accuracy: 0.7368
# Epoch 204/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5526 - categorical_accuracy: 0.7895
# Epoch 205/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6787 - categorical_accuracy: 0.7105
# Epoch 206/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.7194 - categorical_accuracy: 0.6974
# Epoch 207/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.9231 - categorical_accuracy: 0.5921
# Epoch 208/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7062 - categorical_accuracy: 0.6842
# Epoch 209/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.9127 - categorical_accuracy: 0.6184
# Epoch 210/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6240 - categorical_accuracy: 0.7105
# Epoch 211/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6225 - categorical_accuracy: 0.7237
# Epoch 212/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5927 - categorical_accuracy: 0.7105
# Epoch 213/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5660 - categorical_accuracy: 0.7632
# Epoch 214/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5148 - categorical_accuracy: 0.7632
# Epoch 215/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4762 - categorical_accuracy: 0.8026
# Epoch 216/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5625 - categorical_accuracy: 0.7632
# Epoch 217/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4829 - categorical_accuracy: 0.7763
# Epoch 218/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4283 - categorical_accuracy: 0.8289
# Epoch 219/3000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.4323 - categorical_accuracy: 0.8421
# Epoch 220/3000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.4341 - categorical_accuracy: 0.7895
# Epoch 221/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4389 - categorical_accuracy: 0.8158
# Epoch 222/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3872 - categorical_accuracy: 0.8158
# Epoch 223/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.4164 - categorical_accuracy: 0.8421
# Epoch 224/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4933 - categorical_accuracy: 0.7895
# Epoch 225/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4179 - categorical_accuracy: 0.8026
# Epoch 226/3000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.7804 - categorical_accuracy: 0.7105
# Epoch 227/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7060 - categorical_accuracy: 0.6842
# Epoch 228/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.8554 - categorical_accuracy: 0.6316
# Epoch 229/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8138 - categorical_accuracy: 0.6316
# Epoch 230/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7923 - categorical_accuracy: 0.6316
# Epoch 231/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6243 - categorical_accuracy: 0.7237
# Epoch 232/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8864 - categorical_accuracy: 0.6579
# Epoch 233/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8083 - categorical_accuracy: 0.6711
# Epoch 234/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8752 - categorical_accuracy: 0.5921
# Epoch 235/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.7663 - categorical_accuracy: 0.6447
# Epoch 236/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6586 - categorical_accuracy: 0.7763
# Epoch 237/3000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6072 - categorical_accuracy: 0.7500
# Epoch 238/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.7005 - categorical_accuracy: 0.6842
# Epoch 239/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5767 - categorical_accuracy: 0.7368
# Epoch 240/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6239 - categorical_accuracy: 0.7368
# Epoch 241/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5904 - categorical_accuracy: 0.7763
# Epoch 242/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.5366 - categorical_accuracy: 0.8026
# Epoch 243/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.5689 - categorical_accuracy: 0.7632
# Epoch 244/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.4951 - categorical_accuracy: 0.7763
# Epoch 245/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4762 - categorical_accuracy: 0.8026
# Epoch 246/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4739 - categorical_accuracy: 0.8158
# Epoch 247/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4149 - categorical_accuracy: 0.8158
# Epoch 248/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4536 - categorical_accuracy: 0.8026
# Epoch 249/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4576 - categorical_accuracy: 0.7763
# Epoch 250/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3854 - categorical_accuracy: 0.8289
# Epoch 251/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4947 - categorical_accuracy: 0.7763
# Epoch 252/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4046 - categorical_accuracy: 0.7763
# Epoch 253/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4413 - categorical_accuracy: 0.8289
# Epoch 254/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5616 - categorical_accuracy: 0.7763
# Epoch 255/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6625 - categorical_accuracy: 0.7368
# Epoch 256/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6911 - categorical_accuracy: 0.7500
# Epoch 257/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6039 - categorical_accuracy: 0.7368
# Epoch 258/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7469 - categorical_accuracy: 0.6053
# Epoch 259/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6218 - categorical_accuracy: 0.6974
# Epoch 260/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4114 - categorical_accuracy: 0.8421
# Epoch 261/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7954 - categorical_accuracy: 0.6579
# Epoch 262/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4682 - categorical_accuracy: 0.7763
# Epoch 263/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5360 - categorical_accuracy: 0.7763
# Epoch 264/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5702 - categorical_accuracy: 0.7368
# Epoch 265/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4701 - categorical_accuracy: 0.7763
# Epoch 266/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4539 - categorical_accuracy: 0.7763
# Epoch 267/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4387 - categorical_accuracy: 0.8026
# Epoch 268/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4066 - categorical_accuracy: 0.8421
# Epoch 269/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4350 - categorical_accuracy: 0.8553
# Epoch 270/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4624 - categorical_accuracy: 0.7632
# Epoch 271/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8207 - categorical_accuracy: 0.7237
# Epoch 272/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9399 - categorical_accuracy: 0.5395
# Epoch 273/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.8428 - categorical_accuracy: 0.5921
# Epoch 274/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8773 - categorical_accuracy: 0.6447
# Epoch 275/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0466 - categorical_accuracy: 0.5526
# Epoch 276/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7959 - categorical_accuracy: 0.6579
# Epoch 277/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.5911 - categorical_accuracy: 0.7237
# Epoch 278/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6589 - categorical_accuracy: 0.6842
# Epoch 279/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5239 - categorical_accuracy: 0.7763
# Epoch 280/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5874 - categorical_accuracy: 0.7632
# Epoch 281/3000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5128 - categorical_accuracy: 0.8026
# Epoch 282/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4748 - categorical_accuracy: 0.8158
# Epoch 283/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3935 - categorical_accuracy: 0.8816
# Epoch 284/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4041 - categorical_accuracy: 0.8158
# Epoch 285/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3720 - categorical_accuracy: 0.8158
# Epoch 286/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3691 - categorical_accuracy: 0.8684
# Epoch 287/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3303 - categorical_accuracy: 0.8684
# Epoch 288/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3196 - categorical_accuracy: 0.8816
# Epoch 289/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3418 - categorical_accuracy: 0.8421
# Epoch 290/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3903 - categorical_accuracy: 0.8553
# Epoch 291/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3000 - categorical_accuracy: 0.8816
# Epoch 292/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4716 - categorical_accuracy: 0.7368
# Epoch 293/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3289 - categorical_accuracy: 0.8289
# Epoch 294/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4340 - categorical_accuracy: 0.8158
# Epoch 295/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3372 - categorical_accuracy: 0.8421
# Epoch 296/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3142 - categorical_accuracy: 0.8026
# Epoch 297/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3450 - categorical_accuracy: 0.8158
# Epoch 298/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3229 - categorical_accuracy: 0.8421
# Epoch 299/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3437 - categorical_accuracy: 0.8816
# Epoch 300/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2805 - categorical_accuracy: 0.8684
# Epoch 301/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2955 - categorical_accuracy: 0.8684
# Epoch 302/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2860 - categorical_accuracy: 0.9079
# Epoch 303/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.3229 - categorical_accuracy: 0.8947
# Epoch 304/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2371 - categorical_accuracy: 0.9342
# Epoch 305/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2564 - categorical_accuracy: 0.8947
# Epoch 306/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3132 - categorical_accuracy: 0.8816
# Epoch 307/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2643 - categorical_accuracy: 0.8816
# Epoch 308/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3908 - categorical_accuracy: 0.8816
# Epoch 309/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5699 - categorical_accuracy: 0.7500
# Epoch 310/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8232 - categorical_accuracy: 0.7237
# Epoch 311/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6548 - categorical_accuracy: 0.7105
# Epoch 312/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9535 - categorical_accuracy: 0.6447
# Epoch 313/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7089 - categorical_accuracy: 0.7105
# Epoch 314/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5500 - categorical_accuracy: 0.7368
# Epoch 315/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5104 - categorical_accuracy: 0.7763
# Epoch 316/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5040 - categorical_accuracy: 0.7895
# Epoch 317/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5550 - categorical_accuracy: 0.8026
# Epoch 318/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.4108 - categorical_accuracy: 0.8289
# Epoch 319/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3635 - categorical_accuracy: 0.8816
# Epoch 320/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3925 - categorical_accuracy: 0.8684
# Epoch 321/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3171 - categorical_accuracy: 0.8553
# Epoch 322/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3329 - categorical_accuracy: 0.8816
# Epoch 323/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3391 - categorical_accuracy: 0.8421
# Epoch 324/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3198 - categorical_accuracy: 0.8947
# Epoch 325/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2485 - categorical_accuracy: 0.9079
# Epoch 326/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3054 - categorical_accuracy: 0.8421
# Epoch 327/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3517 - categorical_accuracy: 0.8289
# Epoch 328/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2779 - categorical_accuracy: 0.8553
# Epoch 329/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2336 - categorical_accuracy: 0.9211
# Epoch 330/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2319 - categorical_accuracy: 0.8947
# Epoch 331/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2496 - categorical_accuracy: 0.8816
# Epoch 332/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3067 - categorical_accuracy: 0.8816
# Epoch 333/3000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3333 - categorical_accuracy: 0.8816
# Epoch 334/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2690 - categorical_accuracy: 0.8684
# Epoch 335/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2568 - categorical_accuracy: 0.8816
# Epoch 336/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2423 - categorical_accuracy: 0.9079
# Epoch 337/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1906 - categorical_accuracy: 0.9474
# Epoch 338/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2521 - categorical_accuracy: 0.8947
# Epoch 339/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1962 - categorical_accuracy: 0.9211
# Epoch 340/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1714 - categorical_accuracy: 0.9342
# Epoch 341/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1835 - categorical_accuracy: 0.9342
# Epoch 342/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3388 - categorical_accuracy: 0.8421
# Epoch 343/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5584 - categorical_accuracy: 0.7763
# Epoch 344/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5166 - categorical_accuracy: 0.7632
# Epoch 345/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5143 - categorical_accuracy: 0.8158
# Epoch 346/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6084 - categorical_accuracy: 0.6974
# Epoch 347/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5672 - categorical_accuracy: 0.8026
# Epoch 348/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5008 - categorical_accuracy: 0.7368
# Epoch 349/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4548 - categorical_accuracy: 0.7763
# Epoch 350/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4462 - categorical_accuracy: 0.8026
# Epoch 351/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4036 - categorical_accuracy: 0.7632
# Epoch 352/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4179 - categorical_accuracy: 0.8421
# Epoch 353/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4681 - categorical_accuracy: 0.8158
# Epoch 354/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3409 - categorical_accuracy: 0.8026
# Epoch 355/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3293 - categorical_accuracy: 0.8816
# Epoch 356/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3136 - categorical_accuracy: 0.8816
# Epoch 357/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3067 - categorical_accuracy: 0.8553
# Epoch 358/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3733 - categorical_accuracy: 0.7895
# Epoch 359/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2763 - categorical_accuracy: 0.9079
# Epoch 360/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3731 - categorical_accuracy: 0.8289
# Epoch 361/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2123 - categorical_accuracy: 0.9211
# Epoch 362/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2491 - categorical_accuracy: 0.8947
# Epoch 363/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3343 - categorical_accuracy: 0.8684
# Epoch 364/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2286 - categorical_accuracy: 0.9211
# Epoch 365/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2259 - categorical_accuracy: 0.8947
# Epoch 366/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2231 - categorical_accuracy: 0.9342
# Epoch 367/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2052 - categorical_accuracy: 0.9079
# Epoch 368/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1539 - categorical_accuracy: 0.9474
# Epoch 369/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2031 - categorical_accuracy: 0.9211
# Epoch 370/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1780 - categorical_accuracy: 0.9211
# Epoch 371/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1774 - categorical_accuracy: 0.9211
# Epoch 372/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2140 - categorical_accuracy: 0.9211
# Epoch 373/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2074 - categorical_accuracy: 0.9079
# Epoch 374/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2390 - categorical_accuracy: 0.9079
# Epoch 375/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3787 - categorical_accuracy: 0.8421
# Epoch 376/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4494 - categorical_accuracy: 0.8289
# Epoch 377/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3900 - categorical_accuracy: 0.8421
# Epoch 378/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3277 - categorical_accuracy: 0.8421
# Epoch 379/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3951 - categorical_accuracy: 0.8421
# Epoch 380/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3102 - categorical_accuracy: 0.8684
# Epoch 381/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3104 - categorical_accuracy: 0.8816
# Epoch 382/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2776 - categorical_accuracy: 0.8553
# Epoch 383/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2641 - categorical_accuracy: 0.8553
# Epoch 384/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1953 - categorical_accuracy: 0.9342
# Epoch 385/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2168 - categorical_accuracy: 0.8947
# Epoch 386/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2105 - categorical_accuracy: 0.9211
# Epoch 387/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1637 - categorical_accuracy: 0.9474
# Epoch 388/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2175 - categorical_accuracy: 0.9079
# Epoch 389/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2189 - categorical_accuracy: 0.8947
# Epoch 390/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2101 - categorical_accuracy: 0.9079
# Epoch 391/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1922 - categorical_accuracy: 0.9211
# Epoch 392/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3724 - categorical_accuracy: 0.8684
# Epoch 393/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7688 - categorical_accuracy: 0.8158
# Epoch 394/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8415 - categorical_accuracy: 0.7105
# Epoch 395/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7567 - categorical_accuracy: 0.6711
# Epoch 396/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7749 - categorical_accuracy: 0.6974
# Epoch 397/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3149 - categorical_accuracy: 0.8947
# Epoch 398/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3464 - categorical_accuracy: 0.8553
# Epoch 399/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3840 - categorical_accuracy: 0.8421
# Epoch 400/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3474 - categorical_accuracy: 0.8421
# Epoch 401/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2887 - categorical_accuracy: 0.8947
# Epoch 402/3000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2518 - categorical_accuracy: 0.8947
# Epoch 403/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2597 - categorical_accuracy: 0.9342
# Epoch 404/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2538 - categorical_accuracy: 0.9079
# Epoch 405/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2458 - categorical_accuracy: 0.8947
# Epoch 406/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2113 - categorical_accuracy: 0.9342
# Epoch 407/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2117 - categorical_accuracy: 0.9079
# Epoch 408/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1494 - categorical_accuracy: 0.9474
# Epoch 409/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1551 - categorical_accuracy: 0.9474
# Epoch 410/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1303 - categorical_accuracy: 0.9605
# Epoch 411/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1619 - categorical_accuracy: 0.9342
# Epoch 412/3000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1696 - categorical_accuracy: 0.9342
# Epoch 413/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2417 - categorical_accuracy: 0.9211
# Epoch 414/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1433 - categorical_accuracy: 0.9474
# Epoch 415/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1688 - categorical_accuracy: 0.9342
# Epoch 416/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1688 - categorical_accuracy: 0.9474
# Epoch 417/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1198 - categorical_accuracy: 0.9737
# Epoch 418/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1756 - categorical_accuracy: 0.8947
# Epoch 419/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1437 - categorical_accuracy: 0.9474
# Epoch 420/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1072 - categorical_accuracy: 0.9605
# Epoch 421/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1649 - categorical_accuracy: 0.8947
# Epoch 422/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0932 - categorical_accuracy: 0.9868
# Epoch 423/3000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.1262 - categorical_accuracy: 0.9211
# Epoch 424/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1136 - categorical_accuracy: 0.9474
# Epoch 425/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1535 - categorical_accuracy: 0.9342
# Epoch 426/3000
# ...
# Epoch 467/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3950 - categorical_accuracy: 0.8553
# Epoch 468/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3732 - categorical_accuracy: 0.8158
# Epoch 469/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3864 - categorical_accuracy: 0.8158
# Epoch 470/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2307 - categorical_accuracy: 0.8816
# Epoch 471/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3602 - categorical_accuracy: 0.8684
# Epoch 472/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5295 - categorical_accuracy: 0.7763
# Epoch 473/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5459 - categorical_accuracy: 0.8026
# Epoch 474/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.8877 - categorical_accuracy: 0.6447
# Epoch 475/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.7459 - categorical_accuracy: 0.7105
# Epoch 476/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7828 - categorical_accuracy: 0.6711
# Epoch 477/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7435 - categorical_accuracy: 0.6842
# Epoch 478/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6009 - categorical_accuracy: 0.7368
# Epoch 479/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5508 - categorical_accuracy: 0.7632
# Epoch 480/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5934 - categorical_accuracy: 0.6974
# Epoch 481/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5308 - categorical_accuracy: 0.7632
# Epoch 482/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3483 - categorical_accuracy: 0.9342
# Epoch 483/3000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3938 - categorical_accuracy: 0.8553
# Epoch 484/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2933 - categorical_accuracy: 0.9211
# Epoch 485/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2565 - categorical_accuracy: 0.9342
# Epoch 486/3000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2811 - categorical_accuracy: 0.8684
# Epoch 487/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3301 - categorical_accuracy: 0.8026
# Epoch 488/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2884 - categorical_accuracy: 0.9211
# Epoch 489/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2542 - categorical_accuracy: 0.8947
# Epoch 490/3000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3506 - categorical_accuracy: 0.7895
# Epoch 491/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2588 - categorical_accuracy: 0.8947
# Epoch 492/3000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2076 - categorical_accuracy: 0.9342
# Epoch 493/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2366 - categorical_accuracy: 0.8947
# Epoch 494/3000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2112 - categorical_accuracy: 0.8816
# Epoch 495/3000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.1646 - categorical_accuracy: 0.9605
# Epoch 496/3000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2948 - categorical_accuracy: 0.8421
# Epoch 497/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5415 - categorical_accuracy: 0.8026
# Epoch 498/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5640 - categorical_accuracy: 0.7237
# Epoch 499/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2891 - categorical_accuracy: 0.8684
# Epoch 500/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2599 - categorical_accuracy: 0.8947
# Epoch 501/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4461 - categorical_accuracy: 0.8158
# Epoch 502/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2977 - categorical_accuracy: 0.8553
# Epoch 503/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5108 - categorical_accuracy: 0.7632
# Epoch 504/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6667 - categorical_accuracy: 0.6579
# Epoch 505/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6491 - categorical_accuracy: 0.7105
# Epoch 506/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4337 - categorical_accuracy: 0.8421
# Epoch 507/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3174 - categorical_accuracy: 0.8947
# Epoch 508/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.4322 - categorical_accuracy: 0.7237
# Epoch 509/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2409 - categorical_accuracy: 0.8947
# Epoch 510/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.3282 - categorical_accuracy: 0.8816
# Epoch 511/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2262 - categorical_accuracy: 0.9211
# Epoch 512/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2411 - categorical_accuracy: 0.9079
# Epoch 513/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1883 - categorical_accuracy: 0.9211
# Epoch 514/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1878 - categorical_accuracy: 0.9342
# Epoch 515/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1866 - categorical_accuracy: 0.9342
# Epoch 516/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1439 - categorical_accuracy: 0.9605
# Epoch 517/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1794 - categorical_accuracy: 0.9342
# Epoch 518/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1926 - categorical_accuracy: 0.9342
# Epoch 519/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2426 - categorical_accuracy: 0.8289
# Epoch 520/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2381 - categorical_accuracy: 0.8947
# Epoch 521/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.2197 - categorical_accuracy: 0.9079
# Epoch 522/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1315 - categorical_accuracy: 0.9605
# Epoch 523/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1859 - categorical_accuracy: 0.9079
# Epoch 524/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1428 - categorical_accuracy: 0.9079
# Epoch 525/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1565 - categorical_accuracy: 0.9474
# Epoch 526/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1726 - categorical_accuracy: 0.9211
# Epoch 527/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1119 - categorical_accuracy: 0.9605
# Epoch 528/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1242 - categorical_accuracy: 0.9342
# Epoch 529/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1624 - categorical_accuracy: 0.9079
# Epoch 530/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1130 - categorical_accuracy: 0.9605
# Epoch 531/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1313 - categorical_accuracy: 0.9211
# Epoch 532/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1197 - categorical_accuracy: 0.9474
# Epoch 533/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0999 - categorical_accuracy: 0.9474
# Epoch 534/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0756 - categorical_accuracy: 0.9737
# Epoch 535/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0667 - categorical_accuracy: 0.9737
# Epoch 536/3000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0868 - categorical_accuracy: 0.9342
# Epoch 537/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1600 - categorical_accuracy: 0.9211
# Epoch 538/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1545 - categorical_accuracy: 0.9079
# Epoch 539/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1497 - categorical_accuracy: 0.9342
# Epoch 540/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1944 - categorical_accuracy: 0.8684
# Epoch 541/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2813 - categorical_accuracy: 0.8816
# Epoch 542/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3162 - categorical_accuracy: 0.8816
# Epoch 543/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2933 - categorical_accuracy: 0.8684
# Epoch 544/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.3814 - categorical_accuracy: 0.8026
# Epoch 545/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6208 - categorical_accuracy: 0.7632
# Epoch 546/3000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.6801 - categorical_accuracy: 0.7368
# Epoch 547/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7086 - categorical_accuracy: 0.6974
# Epoch 548/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.4086 - categorical_accuracy: 0.8421
# Epoch 549/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3310 - categorical_accuracy: 0.8553
# Epoch 550/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4505 - categorical_accuracy: 0.7895
# Epoch 551/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.4332 - categorical_accuracy: 0.8289
# Epoch 552/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3231 - categorical_accuracy: 0.9079
# Epoch 553/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2790 - categorical_accuracy: 0.9079
# Epoch 554/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2408 - categorical_accuracy: 0.9079
# Epoch 555/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1685 - categorical_accuracy: 0.9342
# Epoch 556/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1856 - categorical_accuracy: 0.9342
# Epoch 557/3000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1494 - categorical_accuracy: 0.9605
# Epoch 558/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1827 - categorical_accuracy: 0.9342
# Epoch 559/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1197 - categorical_accuracy: 0.9737
# Epoch 560/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1163 - categorical_accuracy: 0.9737
# Epoch 561/3000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1087 - categorical_accuracy: 0.9605
# Epoch 562/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1033 - categorical_accuracy: 0.9342
# Epoch 563/3000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0900 - categorical_accuracy: 0.9605
# Epoch 564/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0789 - categorical_accuracy: 0.9868
# Epoch 565/3000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0726 - categorical_accuracy: 0.9868
# Epoch 566/3000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0681 - categorical_accuracy: 0.9868
# Epoch 567/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0671 - categorical_accuracy: 0.9737
# Epoch 568/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0724 - categorical_accuracy: 0.9737
# Epoch 569/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0535 - categorical_accuracy: 0.9737
# Epoch 570/3000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0819 - categorical_accuracy: 0.9605
# Epoch 571/3000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0976 - categorical_accuracy: 0.9605
# Epoch 572/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0861 - categorical_accuracy: 0.9605
# Epoch 573/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0862 - categorical_accuracy: 0.9605
# Epoch 574/3000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0794 - categorical_accuracy: 0.9737
# Epoch 575/3000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0441 - categorical_accuracy: 1.0000
# Epoch 576/3000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0561 - categorical_accuracy: 0.9737
# Epoch 577/3000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0458 - categorical_accuracy: 0.9737
# Epoch 578/3000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0710 - categorical_accuracy: 0.9605
# Epoch 579/3000
# 3/3 [==============================] - ETA: 0s - loss: 0.0462 - categorical_accuracy: 0.9868
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 model.fit(X_train, y_train, epochs=3000, callbacks=[tb_callback])
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1850, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1845     val_logs = {
#    1846         "val_" + name: val for name, val in val_logs.items()
#    1847     }
#    1848     epoch_logs.update(val_logs)
# -> 1850 callbacks.on_epoch_end(epoch, epoch_logs)
#    1851 training_logs = epoch_logs
#    1852 if self.stop_training:
#
# File ~\anaconda3\Lib\site-packages\keras\src\callbacks.py:453, in CallbackList.on_epoch_end(self, epoch, logs)
#     451 logs = self._process_logs(logs)
#     452 for callback in self.callbacks:
# --> 453     callback.on_epoch_end(epoch, logs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\callbacks.py:2841, in TensorBoard.on_epoch_end(self, epoch, logs)
#    2839 def on_epoch_end(self, epoch, logs=None):
#    2840     """Runs metrics and histogram summaries at epoch end."""
# -> 2841     self._log_epoch_metrics(epoch, logs)
#    2843     if self.histogram_freq and epoch % self.histogram_freq == 0:
#    2844         self._log_weights(epoch)
#
# File ~\anaconda3\Lib\site-packages\keras\src\callbacks.py:2906, in TensorBoard._log_epoch_metrics(self, epoch, logs)
#    2904 with tf.summary.record_if(True):
#    2905     if train_logs:
# -> 2906         with self._train_writer.as_default():
#    2907             for name, value in train_logs.items():
#    2908                 tf.summary.scalar("epoch_" + name, value, step=epoch)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:106, in _SummaryContextManager.__exit__(self, *exc)
#     103 def __exit__(self, *exc):
#     104   # Flushes the summary writer in eager mode or in graph functions, but
#     105   # not in legacy graph mode (you're on your own there).
# --> 106   _summary_state.writer.flush()
#     107   _summary_state.writer = self._old_writer
#     108   if self._step is not None:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:370, in _ResourceSummaryWriter.flush(self)
#     368   return
#     369 with ops.device("cpu:0"):
# --> 370   return gen_summary_ops.flush_summary_writer(self._resource)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_summary_ops.py:194, in flush_summary_writer(writer, name)
#     192 if tld.is_eager:
#     193   try:
# --> 194     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     195       _ctx, "FlushSummaryWriter", name, writer)
#     196     return _result
#     197   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]

# %%
actions[np.argmax(y_test[4])]

# %% [markdown]
# # 9. Save Weights

# %%
model.save('prototype1.h5')

# %%
#del model

# %%
model.load_weights('prototype1.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)

# %%
accuracy_score(ytrue, yhat)

# %% [markdown]
# # 11. Test in Real Time

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# Cell In[111], line 5, in prob_viz(res, actions, input_frame, colors)
#       3 output_frame = input_frame.copy()
#       4 for num, prob in enumerate(res):
# ----> 5     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       8 return output_frame
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
sequence.reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 sequence.reverse()
#
# AttributeError: 'int' object has no attribute 'reverse'

# %%
len(sequence)

# %%
sequence.append('def')

# %%
sequence.reverse()

# %%
sequence[-30:]

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
res[np.argmax(res)] > threshold

# %%
(num_sequences,30,1662)

# %%
model.predict(np.expand_dims(X_test[0], axis=0))
